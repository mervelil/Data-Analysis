# %%
# Data Preprocessing
import sklearn.preprocessing as skp
import seaborn as sns
import pandas as pd
df2=sns.load_dataset('tips')

# %%
df=pd.read_csv('MiniProject02/churn.csv')[['gender','InternetService','Contract','MonthlyCharges','PhoneService','StreamingTV','Churn','Age']]
df
# Out:
#       gender InternetService        Contract  MonthlyCharges PhoneService  \
# 0     Female             DSL  Month-to-month           29.85           No
# 1       Male             DSL        One year           56.95          Yes
# 2       Male             DSL  Month-to-month           53.85          Yes
# 3       Male             DSL        One year           42.30           No
# 4     Female     Fiber optic  Month-to-month           70.70          Yes
# ...      ...             ...             ...             ...          ...
# 7038    Male             DSL        One year           84.80          Yes
# 7039  Female     Fiber optic        One year          103.20          Yes
# 7040  Female             DSL  Month-to-month           29.60           No
# 7041    Male     Fiber optic  Month-to-month           74.40          Yes
# 7042    Male     Fiber optic        Two year          105.65          Yes
#
#      StreamingTV Churn  Age
# 0             No    No   29
# ...

# %%
sns.regplot(data=df, x='MonthlyCharges',y='Age')
# Out:
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Age'>

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.regplot(data=df2, x='total_bill',y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.displot(data=df, x='MonthlyCharges')

# %%
sns.displot(data=df2, x='total_bill')

# %%
df2.total_bill.min()
# Out:
# 3.07

# %%
df2.total_bill.max()
# Out:
# 50.81

# %%
df2.tip.min()
# Out:
# 1.0

# %%
df2.tip.max()
# Out:
# 10.0

# %%
df2.total_bill.values.shape
# Out:
# (244,)

# %%
df2.total_bill.values
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 20.29, 13.81, 11.02,
#        18.29, 17.59, 20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07,
#        26.86, 25.28, 14.73, 10.51, 17.92, 27.2 , 22.76, 17.29, 19.44,
#        16.66, 10.07, 32.68, 15.98, 34.83, 13.03, 18.28, 24.71, 21.16,
#        28.97, 22.49,  5.75, 16.32, 22.75, 40.17, 27.28, 12.03, 21.01,
#        12.46, 11.35, 15.38, 44.3 , 22.42, 20.92, 15.36, 20.49, 25.21,
#        18.24, 14.31, 14.  ,  7.25, 38.07, 23.95, 25.71, 17.31, 29.93,
# ...

# %%
df2.total_bill.values.reshape(-1,1)
# Out:
# array([[16.99],
#        [10.34],
#        [21.01],
#        [23.68],
#        [24.59],
#        [25.29],
#        [ 8.77],
#        [26.88],
#        [15.04],
#        [14.78],
#        [10.27],
#        [35.26],
#        [15.42],
#        [18.43],
#        [14.83],
#        [21.58],
#        [10.33],
#        [16.29],
#        [16.97],
#        [20.65],
#        [17.92],
#        [20.29],
#        [15.77],
#        [39.42],
#        [19.82],
#        [17.81],
#        [13.37],
#        [12.69],
#        [21.7 ],
#        [19.65],
#        [ 9.55],
#        [18.35],
#        [15.06],
#        [20.69],
#        [17.78],
#        [24.06],
#        [16.31],
#        [16.93],
#        [18.69],
#        [31.27],
#        [16.04],
#        [17.46],
#        [13.94],
#        [ 9.68],
#        [30.4 ],
#        [18.29],
#        [22.23],
#        [32.4 ],
#        [28.55],
#        [18.04],
#        [12.54],
#        [10.29],
#        [34.81],
#        [ 9.94],
#        [25.56],
# ...

# %%
# Normalization --> [0,1]
scaler=skp.MinMaxScaler()
df['total_bill']=scaler.fit_transform(df2.total_bill.values.reshape(-1,1))
df['tip']=scaler.fit_transform(df2.tip.values.reshape(-1,1))

# %%
df2[['total_bill','tip']=scaler.fit_transform(df2[['total_bill','tip']])
# Out:
# array([[0.29157939, 0.00111111],
#        [0.1522832 , 0.07333333],
#        [0.3757855 , 0.27777778],
#        [0.43171345, 0.25666667],
#        [0.45077503, 0.29      ],
#        [0.46543779, 0.41222222],
#        [0.11939673, 0.11111111],
#        [0.49874319, 0.23555556],
#        [0.25073314, 0.10666667],
#        [0.24528697, 0.24777778],
#        [0.15081693, 0.07888889],
#        [0.67427734, 0.44444444],
#        [0.25869292, 0.06333333],
#        [0.32174277, 0.22222222],
#        [0.24633431, 0.22444444],
#        [0.38772518, 0.32444444],
#        [0.15207373, 0.07444444],
#        [0.27691663, 0.30111111],
#        [0.29116045, 0.27777778],
#        [0.36824466, 0.26111111],
#        [0.31105991, 0.34222222],
#        [0.36070381, 0.19444444],
#        [0.2660243 , 0.13666667],
#        [0.761416  , 0.73111111],
#        [0.35085882, 0.24222222],
#        [0.30875576, 0.14888889],
#        [0.21575199, 0.11111111],
#        [0.20150817, 0.11111111],
# ...

# %%
newr_total_bill.min()
# Out:
# 0.0

# %%
newr_total_bill.max()
# Out:
# 0.9999999999999999

# %%
sns.displot(newr_total_bill)

# %% [markdown]
# ## Categorical --> Continuous

# %%
# Label Encoding
scaler=skp.LabelEncoder()
df2['day']=scaler.fit_transform(df2['day'])

# %%
df2
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No    2  Dinner     2
# 1         10.34  1.66    Male     No    2  Dinner     3
# 2         21.01  3.50    Male     No    2  Dinner     3
# 3         23.68  3.31    Male     No    2  Dinner     2
# 4         24.59  3.61  Female     No    2  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 239       29.03  5.92    Male     No    1  Dinner     3
# 240       27.18  2.00  Female    Yes    1  Dinner     2
# 241       22.67  2.00    Male    Yes    1  Dinner     2
# 242       17.82  1.75    Male     No    1  Dinner     2
# 243       18.78  3.00  Female     No    3  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Label Binarization
scaler=skp.LabelBinarizer()
bins=scaler.fit_transform(df2['day'])

# %%
labels=sorted(df2.day.unique())

# %%
d=pd.DataFrame(bins, columns=labels)
pd.concat([df2,d], axis=1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  Fri  Sat  Sun  Thur
# 0         16.99  1.01  Female     No   Sun  Dinner     2    0    0    1     0
# 1         10.34  1.66    Male     No   Sun  Dinner     3    0    0    1     0
# 2         21.01  3.50    Male     No   Sun  Dinner     3    0    0    1     0
# 3         23.68  3.31    Male     No   Sun  Dinner     2    0    0    1     0
# 4         24.59  3.61  Female     No   Sun  Dinner     4    0    0    1     0
# ..          ...   ...     ...    ...   ...     ...   ...  ...  ...  ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    0    1    0     0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    0    1    0     0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    0    1    0     0
# 242       17.82  1.75    Male     No   Sat  Dinner     2    0    1    0     0
# 243       18.78  3.00  Female     No  Thur  Dinner     2    0    0    0     1
#
# [244 rows x 11 columns]

# %% [markdown]
# ## Continuous --> Categorical

# %%
# using numpy
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np
bins=np.linspace(df2['tip'].min(), df2['tip'].max(),4)
labels=['small','medium','large']

# %%
df2['tip']=pd.cut(df2['tip'], bins=bins, labels=labels)

# %%
df2.tip.unique()
# Out:
# ['small', 'medium', 'large', NaN]
# Categories (3, object): ['small' < 'medium' < 'large']

# %%
# Using KBinsDiscretizer
scaler=skp.KBinsDiscretizer(n_bins=3, encode='ordinal', strategy='kmeans')
digital_labels=scaler.fit_transform(df2['tip'].values.reshape(-1,1))
digital_labels=digital_labels.astype(str)
digital_labels[digital_labels=='0.0']='small'
digital_labels[digital_labels=='1.0']='medium'
digital_labels[digital_labels=='2.0']='high'

# %%
df2['tip_as_cat']=digital_labels

# %%
df2
# Out:
#      total_bill   tip     sex smoker   day    time  size tip_as_cat
# 0         16.99  1.01  Female     No   Sun  Dinner     2      small
# 1         10.34  1.66    Male     No   Sun  Dinner     3      small
# 2         21.01  3.50    Male     No   Sun  Dinner     3       high
# 3         23.68  3.31    Male     No   Sun  Dinner     2       high
# 4         24.59  3.61  Female     No   Sun  Dinner     4       high
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       high
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2      small
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2      small
# 242       17.82  1.75    Male     No   Sat  Dinner     2      small
# 243       18.78  3.00  Female     No  Thur  Dinner     2     medium
#
# [244 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
plt.boxplot(df2.tip);

# %%
# Summary
# Reading data
    # pd.read_csv()
    # f=open()
    # requests.get(URL)
    # np.loadtxt
# Generating the data
#     np.random.randint()
#     stats.norm.rvs
#     stats.binom.rvs
# Data Discovery
    # df.types
    # df.info
    # df.head
    # df.index
    # df[col]value_counts()
    # df.describe()
    # df.shape()
# Descriptive statics
    # plt.hist(df[col])
    # plt.boxplot(df[col])
    # df.isna()
    # df[col].mean()
    # df[col].median()
    # df[col].std()
# Data pre-processing
    # df.fillna()
    # df.dropna()
    # df.interpolate()
    # df.col[stats.zscore(df[col])<3]
    # df[df.apply((stats.zscore(df[col])<3).all())]
#     df.reset_index()
#     df.drop(rows, axis=0)
#     df.drop(col, axis=1)
#     continuous --> categorical
#     categorical --> continuous
#     Normalization
# Analysis
    # apply queries
#     df.loc[row_names, col_names]
#     df.iloc[row_ids, col_ids]
#     df[col_name][row_name]
#     df.groupby().agg()
#     df.pivot_table(index, columns, values)
#     pd.crosstab(index, columns)
#     # visualize the data
#     plt.hist()
#     plt.pie()
#     plt.scatter()
#     plt.bar()
#     plt.plot()
#     sns.displot()
#     sns.countplot()
#     sns.baplot()
#     sns.regplot()
#     sns.lmplot()
#     sns.kdeplot()
#     sns.FactGrid(data, col, rows).map
#     sns.PairGrid()

# Hypothesis Test (sample --> population)
# stats.ttest_1samp(sample_data, 30)  ---> p-value<0.05 ==> reject the null hypothesis
# stats.ttest_ind(var1, var2)         ---> p-value<0.05 ==> reject the null hypothesis
# stats.f_oneway(var2, var2, var3)    ---> p-value<0.05 ==> reject the null hypothesis

# use machine learning tech to extract knowledge
# clustering
# classification
# regresssion
